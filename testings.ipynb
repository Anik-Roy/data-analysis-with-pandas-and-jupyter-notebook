# %%
import pandas
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '.venv',
#  'dictionary_compact.json',
#  'result.csv',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.xlsx',
#  'testings.ipynb',
#  'test_lu_result_scrappig.ipynb',
#  'views.py']

# %%
df1 = pandas.read_csv("supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df2 = pandas.read_excel("supermarkets.xlsx", sheet_name=0)
df2
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df3 = pandas.read_csv("supermarkets-commas.txt")
df3
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df4 = pandas.read_csv("supermarkets-semi-colons.txt", sep=';')
df4
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5 = pandas.read_csv("supermarkets.csv")
df5
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df5.set_index("ID")
# Out:
#             Address           City             State Country Supermarket Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA          Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA      Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA      Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA       Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA          Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA       Richvalley
#
#     Number of Employees
# ID
# 1                     8
# 2                    15
# 3                    25
# 4                    10
# 5                    12
# 6                    20

# %%
df5
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df5.set_index("ID", inplace=True)
df5
# Out:
#             Address           City             State Country Supermarket Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA          Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA      Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA      Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA       Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA          Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA       Richvalley
#
#     Number of Employees
# ID
# 1                     8
# 2                    15
# 3                    25
# 4                    10
# 5                    12
# 6                    20

# %%
df5.loc['2':'4','Address':'Country']
# Out:
#            Address           City             State Country
# ID
# 2   735 Dolores St  San Francisco          CA 94119     USA
# 3      332 Hill St  San Francisco  California 94114     USA
# 4     3995 23rd St  San Francisco          CA 94114     USA

# %%
df5
# Out:
#             Address           City             State Country Supermarket Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA          Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA      Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA      Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA       Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA          Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA       Richvalley
#
#     Number of Employees
# ID
# 1                     8
# 2                    15
# 3                    25
# 4                    10
# 5                    12
# 6                    20

# %%
df5.iloc[1:3, 0:3]
# Out:
#            Address           City             State
# ID
# 2   735 Dolores St  San Francisco          CA 94119
# 3      332 Hill St  San Francisco  California 94114

# %%
df5.drop("City", 1)
# Out:
#             Address             State Country Supermarket Name  \
# ID
# 1      3666 21st St          CA 94114     USA          Madeira
# 2    735 Dolores St          CA 94119     USA      Bready Shop
# 3       332 Hill St  California 94114     USA      Super River
# 4      3995 23rd St          CA 94114     USA       Ben's Shop
# 5   1056 Sanchez St        California     USA          Sanchez
# 6   551 Alvarado St          CA 94114     USA       Richvalley
#
#     Number of Employees
# ID
# 1                     8
# 2                    15
# 3                    25
# 4                    10
# 5                    12
# 6                    20

# %%
df5.drop(3, 0)
# Out:
#             Address           City       State Country Supermarket Name  \
# ID
# 1      3666 21st St  San Francisco    CA 94114     USA          Madeira
# 2    735 Dolores St  San Francisco    CA 94119     USA      Bready Shop
# 4      3995 23rd St  San Francisco    CA 94114     USA       Ben's Shop
# 5   1056 Sanchez St  San Francisco  California     USA          Sanchez
# 6   551 Alvarado St  San Francisco    CA 94114     USA       Richvalley
#
#     Number of Employees
# ID
# 1                     8
# 2                    15
# 4                    10
# 5                    12
# 6                    20

# %%
df5
# Out:
#             Address           City             State Country Supermarket Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA          Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA      Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA      Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA       Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA          Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA       Richvalley
#
#     Number of Employees
# ID
# 1                     8
# 2                    15
# 3                    25
# 4                    10
# 5                    12
# 6                    20

# %%
df5.drop(df5.index[3:5], 0)
# Out:
#             Address           City             State Country Supermarket Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA          Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA      Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA      Super River
# 6   551 Alvarado St  San Francisco          CA 94114     USA       Richvalley
#
#     Number of Employees
# ID
# 1                     8
# 2                    15
# 3                    25
# 6                    20

# %%
df5
# Out:
#             Address           City             State Country Supermarket Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA          Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA      Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA      Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA       Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA          Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA       Richvalley
#
#     Number of Employees
# ID
# 1                     8
# 2                    15
# 3                    25
# 4                    10
# 5                    12
# 6                    20

# %%
df5.drop(df5.columns[1:3], 1)
# Out:
#             Address Country Supermarket Name  Number of Employees
# ID
# 1      3666 21st St     USA          Madeira                    8
# 2    735 Dolores St     USA      Bready Shop                   15
# 3       332 Hill St     USA      Super River                   25
# 4      3995 23rd St     USA       Ben's Shop                   10
# 5   1056 Sanchez St     USA          Sanchez                   12
# 6   551 Alvarado St     USA       Richvalley                   20

# %%
df5.columns
# Out:
# Index(['Address', 'City', 'State', 'Country', 'Supermarket Name',
#        'Number of Employees'],
#       dtype='object')

# %%
df5
# Out:
#             Address           City             State Country Supermarket Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA          Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA      Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA      Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA       Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA          Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA       Richvalley
#
#     Number of Employees
# ID
# 1                     8
# 2                    15
# 3                    25
# 4                    10
# 5                    12
# 6                    20

# %%
df5["Continent"] = df5.shape[0]*["North America"]
df5
# Out:
#             Address           City             State Country Supermarket Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA          Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA      Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA      Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA       Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA          Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA       Richvalley
#
#     Number of Employees      Continent
# ID
# 1                     8  North America
# 2                    15  North America
# 3                    25  North America
# 4                    10  North America
# 5                    12  North America
# 6                    20  North America

# %%
df5["Continent"] = df5["Country"]+","+df5["Continent"]
df5
# Out:
#             Address           City             State Country Supermarket Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA          Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA      Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA      Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA       Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA          Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA       Richvalley
#
#    Number of Employees                          Continent
# ID
# 1                    8  USA,USA,USA,USA,USA,North America
# 2                   15  USA,USA,USA,USA,USA,North America
# 3                   25  USA,USA,USA,USA,USA,North America
# 4                   10  USA,USA,USA,USA,USA,North America
# 5                   12  USA,USA,USA,USA,USA,North America
# 6                   20  USA,USA,USA,USA,USA,North America

# %%
df5_t = df5.T

# %%
df5_t
# Out:
# ID                                                   1  \
# Address                                   3666 21st St
# City                                     San Francisco
# State                                         CA 94114
# Country                                            USA
# Supermarket Name                               Madeira
# Number of Employees                                  8
# Continent            USA,USA,USA,USA,USA,North America
#
# ID                                                   2  \
# Address                                 735 Dolores St
# City                                     San Francisco
# State                                         CA 94119
# Country                                            USA
# Supermarket Name                           Bready Shop
# Number of Employees                                 15
# Continent            USA,USA,USA,USA,USA,North America
#
# ID                                                   3  \
# ...

# %%
df5_t[7] = ["My Address", "My City", "My State", "My Country", "My Supermarket Name", 10, "My Continent"]

# %%
df5_t
# Out:
# ID                                                   1  \
# Address                                   3666 21st St
# City                                     San Francisco
# State                                         CA 94114
# Country                                            USA
# Supermarket Name                               Madeira
# Number of Employees                                  8
# Continent            USA,USA,USA,USA,USA,North America
#
# ID                                                   2  \
# Address                                 735 Dolores St
# City                                     San Francisco
# State                                         CA 94119
# Country                                            USA
# Supermarket Name                           Bready Shop
# Number of Employees                                 15
# Continent            USA,USA,USA,USA,USA,North America
#
# ID                                                   3  \
# ...

# %%
df5 = df5_t.T

# %%
df5
# Out:
#             Address           City             State     Country  \
# ID
# 1      3666 21st St  San Francisco          CA 94114         USA
# 2    735 Dolores St  San Francisco          CA 94119         USA
# 3       332 Hill St  San Francisco  California 94114         USA
# 4      3995 23rd St  San Francisco          CA 94114         USA
# 5   1056 Sanchez St  San Francisco        California         USA
# 6   551 Alvarado St  San Francisco          CA 94114         USA
# 7        My Address        My City          My State  My Country
#
#        Supermarket Name Number of Employees                          Continent
# ID
# 1               Madeira                   8  USA,USA,USA,USA,USA,North America
# 2           Bready Shop                  15  USA,USA,USA,USA,USA,North America
# 3           Super River                  25  USA,USA,USA,USA,USA,North America
# 4            Ben's Shop                  10  USA,USA,USA,USA,USA,North America
# ...

# %%
from geopy.geocoders import Nominatim

# %%
nom = Nominatim(user_agent="my-application")
nom.geocode("3995 23rd St, San Francisco, CA 94114")
# Out:
# Location(3995, 23rd Street, Noe Valley, San Francisco, San Francisco City and County, California, 94114, United States of America, (37.7529648, -122.4317141, 0.0))

# %%
df6 = pandas.read_csv("supermarkets.csv")
df6
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df6["Address"] = df6["Address"]+", "+df6["City"]+", "+df6["State"]+", "+df6["Country"]

# %%
df6
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country Supermarket Name  Number of Employees
# 0          CA 94114     USA          Madeira                    8
# 1          CA 94119     USA      Bready Shop                   15
# 2  California 94114     USA      Super River                   25
# 3          CA 94114     USA       Ben's Shop                   10
# 4        California     USA          Sanchez                   12
# 5          CA 94114     USA       Richvalley                   20

# %%
df6["Coordinates"] = df6["Address"].apply(nom.geocode)

# %%
df6
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country Supermarket Name  Number of Employees  \
# 0          CA 94114     USA          Madeira                    8
# 1          CA 94119     USA      Bready Shop                   15
# 2  California 94114     USA      Super River                   25
# 3          CA 94114     USA       Ben's Shop                   10
# 4        California     USA          Sanchez                   12
# ...

# %%
df6["Latitude"] = df6['Coordinates'].apply(lambda x: x.latitude if x != None else None)
df6["Longitude"] = df6['Coordinates'].apply(lambda x: x.longitude if x != None else None)
df6
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country Supermarket Name  Number of Employees  \
# 0          CA 94114     USA          Madeira                    8
# 1          CA 94119     USA      Bready Shop                   15
# 2  California 94114     USA      Super River                   25
# 3          CA 94114     USA       Ben's Shop                   10
# 4        California     USA          Sanchez                   12
# ...
